# %% [markdown]
# <a href="https://colab.research.google.com/github/NeilCaccam/CPE-311-CPE22S3---Computational-Thinking-with-Python/blob/main/SW%2011.1/CACCAM___Seatwork_11_1_%7C_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - PART 1

# %%
import matplotlib.pyplot as plt

# Given values
b = 1
w1 = 3
x1 = 0

# Linear regression prediction: y = w1*x1 + b
y = w1 * x1 + b

print("Prediction:", y)

# Plot
x_vals = np.linspace(-5, 5, 100)
y_vals = w1 * x_vals + b

plt.plot(x_vals, y_vals, label="y = 3x + 1")
plt.scatter(x1, y, color='red', label="Prediction point")
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear Regression")
plt.grid()
plt.show()
# Out:
# Prediction: 1

# %% [markdown]
# Analysis:
# - The prediction is 1 because the input 𝑥 1 = 0, so the term 𝑤 1 ⋅ 𝑥 1  becomes 0. That means the output depends only on the bias 𝑏 . So, the model outputs the bias value, which is 1.

# %% [markdown]
# - PART 2

# %%
# Given weights and bias
b = 1
w1 = 3
w2 = -2
w3 = 4

# Example 1
x1_1, x2_1, x3_1 = 3, -1, 2
y1 = w1*x1_1 + w2*x2_1 + w3*x3_1 + b

# Example 2
x1_2, x2_2, x3_2 = 10, 0, -10
y2 = w1*x1_2 + w2*x2_2 + w3*x3_2 + b

print("Prediction for Example 1:", y1)
print("Prediction for Example 2:", y2)
# Out:
# Prediction for Example 1: 20
# Prediction for Example 2: -9

# %% [markdown]
# Analysis:
# - 20 for Example 1 and -9 for Example 2. Example 1 is positive because all features contribute positively overall, while Example 2 becomes negative due to the strong negative effect of x 3 ​
