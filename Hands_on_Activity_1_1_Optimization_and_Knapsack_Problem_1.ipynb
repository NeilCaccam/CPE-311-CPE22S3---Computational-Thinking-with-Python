# %% [markdown]
# # Hands-on Activity 1.1 | Optimization and Knapsack Problem

# %% [markdown]
# #### Objective(s):
#
# This activity aims to demonstrate how to apply  greedy and brute force algorithms to solve optimization problems

# %% [markdown]
# #### Intended Learning Outcomes (ILOs):
# * Demonstrate how to solve knapsacks problems using greedy algorithm
# * Demonstrate how to  solve knapsacks problems using brute force algorithm

# %% [markdown]
# #### Resources:
# * Jupyter Notebook

# %% [markdown]
# #### Procedures:

# %% [markdown]
# 1. Create a Food class that defines the following:
# * name of the food
# * value of the food
# * calories of the food
#
# 2. Create the following methods inside the Food class:
# * A method that returns the value of the food
# * A method that returns the cost of the food
# * A method that calculates the density of the food (Value / Cost)
# * A method that returns a string to display the name, value and calories of the food

# %%
class Food(object):
    def __init__(self, n, v, w):
        # Make the variables private
        self.name = n
        self.value = v
        self.calories = w
    def getValue(self):
        return self.value
    def getCost(self):
        return self.calories
    def density(self):
        return self.getValue()/self.getCost()
    def __str__(self):
        return self.name + ': <' + str(self.value)+ ', ' + str(self.calories) + '>'

# %% [markdown]
# 3. Create a buildMenu method that builds the name, value and calories of the food

# %%
def buildMenu(names, values, calories):
    menu = []
    for i in range(len(values)):
        menu.append(Food(names[i], values[i],calories[i]))
    return menu

# %% [markdown]
# 4. Create a method greedy to return total value and cost of added food based on the desired maximum cost

# %%
def greedy(items, maxCost, keyFunction):
    """Assumes items a list, maxCost >= 0,         keyFunction maps elements of items to numbers"""
    itemsCopy = sorted(items, key = keyFunction,
                       reverse = True)
    result = []
    totalValue, totalCost = 0.0, 0.0
    for i in range(len(itemsCopy)):
        if (totalCost+itemsCopy[i].getCost()) <= maxCost:
            result.append(itemsCopy[i])
            totalCost += itemsCopy[i].getCost()
            totalValue += itemsCopy[i].getValue()
    return (result, totalValue)

# %% [markdown]
# 5. Create a testGreedy method to test the greedy method

# %%
def testGreedy(items, constraint, keyFunction):
    taken, val = greedy(items, constraint, keyFunction)
    print('Total value of items taken =', val)
    for item in taken:
        print('   ', item)

# %%
def testGreedys(foods, maxUnits):
    print('Use greedy by value to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.getValue)
    print('\nUse greedy by cost to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, lambda x: 1/Food.getCost(x))
    print('\nUse greedy by density to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.density)

# %% [markdown]
# 6. Create arrays of food name, values and calories
# 7. Call the buildMenu to create menu for food
# 8. Use testGreedys method to pick food according to the desired calories

# %%
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
foods = buildMenu(names, values, calories)
testGreedys(foods, 2000)
# Out:
# Use greedy by value to allocate 2000 calories
# Total value of items taken = 603.0
#     burger: <100, 354>
#     pizza: <95, 258>
#     beer: <90, 154>
#     fries: <90, 365>
#     wine: <89, 123>
#     cola: <79, 150>
#     apple: <50, 95>
#     donut: <10, 195>
#
# Use greedy by cost to allocate 2000 calories
# Total value of items taken = 603.0
#     apple: <50, 95>
#     wine: <89, 123>
#     cola: <79, 150>
#     beer: <90, 154>
#     donut: <10, 195>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#
# Use greedy by density to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123>
#     beer: <90, 154>
#     cola: <79, 150>
#     apple: <50, 95>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#     donut: <10, 195>

# %% [markdown]
# Task 1: Change the maxUnits to 100

# %%
#type your code here

names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
foods = buildMenu(names, values, calories)
testGreedys(foods, 100)
# Out:
# Use greedy by value to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>
#
# Use greedy by cost to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>
#
# Use greedy by density to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>

# %% [markdown]
# Task 2: Modify codes to add additional weight (criterion) to select food items.

# %%
class Food(object):
    def __init__(self, n, v, w, q=1):  
        self.name = n
        self.value = v 
        self.calories = w
        self.quantity = q  
    
    def getValue(self):
        return self.value
    
    def getCost(self):
        return self.calories
    
    def getQuantity(self):  
        return self.quantity
    
    def density(self):
        return self.getValue()/self.getCost()
    
    def __str__(self):
        return self.name + ': <' + str(self.value) + ', ' + str(self.calories) + ', qty:' + str(self.quantity) + '>'


def buildMenu(names, values, calories, quantities=None):
    menu = []
    for i in range(len(values)):
        if quantities:  
            menu.append(Food(names[i], values[i], calories[i], quantities[i]))
    return menu

def greedy(items, maxCost, keyFunction):
    itemsCopy = sorted(items, key = keyFunction, reverse = True)
    result = []
    totalValue, totalCost = 0.0, 0.0
    for i in range(len(itemsCopy)):
        if (totalCost+itemsCopy[i].getCost()) <= maxCost:
            result.append(itemsCopy[i])
            totalCost += itemsCopy[i].getCost()
            totalValue += itemsCopy[i].getValue()
    return (result, totalValue)


def testGreedy(items, constraint, keyFunction):
    taken, val = greedy(items, constraint, keyFunction)
    print('Total value of items taken =', val)
    for item in taken:
        print('   ', item)


def testGreedys(foods, maxUnits):
    print('Use greedy by value to allocate', maxUnits, 'calories')
    testGreedy(foods, maxUnits, Food.getValue)
    print('\nUse greedy by cost to allocate', maxUnits, 'calories')
    testGreedy(foods, maxUnits, lambda x: 1/Food.getCost(x))
    print('\nUse greedy by density to allocate', maxUnits, 'calories')
    testGreedy(foods, maxUnits, Food.density)
    print('\nUse greedy by quantity to allocate', maxUnits, 'calories')
    testGreedy(foods, maxUnits, Food.getQuantity)
    
names = ['wine', 'beer', 'pizza', 'burger', 'fries', 'cola', 'apple', 'donut']
values = [89, 90, 95, 100, 90, 79, 50, 10]
calories = [123, 154, 258, 354, 365, 150, 95, 195]
quantities = [3, 8, 2, 4, 6, 10, 1, 5]  


foods = buildMenu(names, values, calories, quantities)
testGreedys(foods, 2000)
# Out:
# Use greedy by value to allocate 2000 calories
# Total value of items taken = 603.0
#     burger: <100, 354, qty:4>
#     pizza: <95, 258, qty:2>
#     beer: <90, 154, qty:8>
#     fries: <90, 365, qty:6>
#     wine: <89, 123, qty:3>
#     cola: <79, 150, qty:10>
#     apple: <50, 95, qty:1>
#     donut: <10, 195, qty:5>
#
# Use greedy by cost to allocate 2000 calories
# Total value of items taken = 603.0
#     apple: <50, 95, qty:1>
#     wine: <89, 123, qty:3>
#     cola: <79, 150, qty:10>
#     beer: <90, 154, qty:8>
#     donut: <10, 195, qty:5>
#     pizza: <95, 258, qty:2>
#     burger: <100, 354, qty:4>
#     fries: <90, 365, qty:6>
#
# Use greedy by density to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123, qty:3>
#     beer: <90, 154, qty:8>
#     cola: <79, 150, qty:10>
#     apple: <50, 95, qty:1>
#     pizza: <95, 258, qty:2>
#     burger: <100, 354, qty:4>
#     fries: <90, 365, qty:6>
#     donut: <10, 195, qty:5>
#
# ...

# %% [markdown]
# Task 3: Test your modified code to test the greedy algorithm to select food items with your additional weight.

# %%
# type your code here

foods = buildMenu(names, values, calories, quantities)
testGreedys(foods, 100)
# Out:
# Use greedy by value to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95, qty:1>
#
# Use greedy by cost to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95, qty:1>
#
# Use greedy by density to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95, qty:1>
#
# Use greedy by quantity to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95, qty:1>

# %% [markdown]
# 9. Create method to use  Bruteforce algorithm instead of greedy algorithm

# %%
def maxVal(toConsider, avail):
    """Assumes toConsider a list of items, avail a weight
       Returns a tuple of the total value of a solution to the
         0/1 knapsack problem and the items of that solution"""
    if toConsider == [] or avail == 0:
        result = (0, ())
    elif toConsider[0].getCost() > avail:
        #Explore right branch only
        result = maxVal(toConsider[1:], avail)
    else:
        nextItem = toConsider[0]
        #Explore left branch
        withVal, withToTake = maxVal(toConsider[1:],
                                     avail - nextItem.getCost())
        withVal += nextItem.getValue()
        #Explore right branch
        withoutVal, withoutToTake = maxVal(toConsider[1:], avail)
        #Choose better branch
        if withVal > withoutVal:
            result = (withVal, withToTake + (nextItem,))
        else:
            result = (withoutVal, withoutToTake)
    return result

# %%
def testMaxVal(foods, maxUnits, printItems = True):
    print('Use search tree to allocate', maxUnits,
          'calories')
    val, taken = maxVal(foods, maxUnits)
    print('Total costs of foods taken =', val)
    if printItems:
        for item in taken:
            print('   ', item)

# %%
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
foods = buildMenu(names, values, calories)
testMaxVal(foods, 2400)
# Out:
# Use search tree to allocate 2400 calories
# Total costs of foods taken = 603
#     donut: <10, 195>
#     apple: <50, 95>
#     cola: <79, 150>
#     fries: <90, 365>
#     burger: <100, 354>
#     pizza: <95, 258>
#     beer: <90, 154>
#     wine: <89, 123>

# %% [markdown]
# #### Supplementary Activity:

# %% [markdown]
# * Choose a real-world problem that solves knapsacks problem
# * Use the greedy and brute force algorithm to solve knapsacks problem

# %%
#NEW PROBLEM

class Vehicle(object):
    def __init__(self, n, v, f):
        self.name = n
        self.value = v
        self.fuel = f

    def getValue(self):
        return self.value
    def getCost(self):
        return self.fuel
    def density(self):
        return self.getValue() / self.getCost()
    def __str__(self):
        return self.name + ': <' + str(self.value) + ', ' + str(self.fuel) + '>'
    
def buildGarage(names, values, fuel):
    garage = []
    for i in range(len(values)):
        garage.append(Vehicle(names[i], values[i], fuel[i]))
    return garage

# %%
def greedy(items, maxCost, keyFunction):
    itemsCopy = sorted(items, key=keyFunction, reverse=True)
    result = []
    totalValue, totalCost = 0.0, 0.0

    for i in range(len(itemsCopy)):
        if (totalCost + itemsCopy[i].getCost()) <= maxCost:
            result.append(itemsCopy[i])
            totalCost += itemsCopy[i].getCost()
            totalValue += itemsCopy[i].getValue()

    return (result, totalValue)


def testGreedy(items, constraint, keyFunction):
    taken, val = greedy(items, constraint, keyFunction)
    print('Total value of vehicles selected =', val)
    for item in taken:
        print('   ', item)

def testGreedys(vehicles, maxFuel):
    print('Use greedy by value to allocate', maxFuel, 'fuel units')
    testGreedy(vehicles, maxFuel, Vehicle.getValue)
    print('\nUse greedy by fuel cost to allocate', maxFuel, 'fuel units')
    testGreedy(vehicles, maxFuel, lambda x: 1 / Vehicle.getCost(x))
    print('\nUse greedy by efficiency (value/fuel) to allocate', maxFuel, 'fuel units')
    testGreedy(vehicles, maxFuel, Vehicle.density)

# %%
names = ['Sedan', 'SUV', 'Motorcycle', 'Truck', 'Van', 'Electric Car', 'Bus', 'Taxi']
values = [70, 85, 60, 90, 75, 95, 88, 80]
fuel = [50, 80, 30, 120, 90, 40, 150, 60]

vehicles = buildGarage(names, values, fuel)
testGreedys(vehicles, 300)
# Out:
# Use greedy by value to allocate 300 fuel units
# Total value of vehicles selected = 350.0
#     Electric Car: <95, 40>
#     Truck: <90, 120>
#     SUV: <85, 80>
#     Taxi: <80, 60>
#
# Use greedy by fuel cost to allocate 300 fuel units
# Total value of vehicles selected = 390.0
#     Motorcycle: <60, 30>
#     Electric Car: <95, 40>
#     Sedan: <70, 50>
#     Taxi: <80, 60>
#     SUV: <85, 80>
#
# Use greedy by efficiency (value/fuel) to allocate 300 fuel units
# Total value of vehicles selected = 390.0
#     Electric Car: <95, 40>
#     Motorcycle: <60, 30>
#     Sedan: <70, 50>
#     Taxi: <80, 60>
#     SUV: <85, 80>

# %%
    #BRUTEFORCE

def maxVal(toConsider, avail):
     if toConsider == [] or avail == 0:
        result = (0, ())

     elif toConsider[0].getCost() > avail:
        # Explore right branch only
        result = maxVal(toConsider[1:], avail)
     else:
        nextVehicle = toConsider[0]

        # Explore left branch (take vehicle)
        withVal, withToTake = maxVal(
            toConsider[1:], avail - nextVehicle.getCost())
        withVal += nextVehicle.getValue()

        # Explore right branch (do not take vehicle)
        withoutVal, withoutToTake = maxVal(
            toConsider[1:], avail)

        # Choose better branch
        if withVal > withoutVal:
            result = (withVal, withToTake + (nextVehicle,))
        else:
            result = (withoutVal, withoutToTake)

     return result


def testMaxVal(vehicles, maxFuel, printItems=True):
        print('Use search tree to allocate', maxFuel, 'fuel units')
        val, taken = maxVal(vehicles, maxFuel)
        print('Total value of vehicles taken =', val)
        if printItems:
            for item in taken:
                print('   ', item)

# %%
names = ['Sedan', 'SUV', 'Motorcycle', 'Truck', 'Van',
         'Electric Car', 'Bus', 'Taxi']
values = [70, 85, 60, 90, 75, 95, 88, 80]
fuel = [50, 80, 30, 120, 90, 40, 150, 60]

vehicles = buildGarage(names, values, fuel)
testMaxVal(vehicles, 300)
# Out:
# Use search tree to allocate 300 fuel units
# Total value of vehicles taken = 395
#     Taxi: <80, 60>
#     Electric Car: <95, 40>
#     Van: <75, 90>
#     Motorcycle: <60, 30>
#     SUV: <85, 80>

# %% [markdown]
# #### Conclusion:

# %% [markdown]
# In this activity, i learned how to apply greedy and brute force algorithms to solve optimization problems, especially the knapsack problem. The greedy algorithm helps us choose items step by step based on value, cost, or efficiency, which makes the solution faster but not always the best. On the other hand, the brute force algorithm checks all possible combinations, so it gives the best or optimal solution, but it takes more time. Through this activity, i were able to understand the difference between the two algorithms and how they work in solving knapsack problems. Overall, this helped us improve our understanding of optimization and algorithm problem solving. Because when performing this activity i encountered and learned debugging techniques and proper back tracking to the codes
